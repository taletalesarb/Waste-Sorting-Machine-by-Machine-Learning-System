# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2022-01-16 16:51:41--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M   108MB/s    in 2.2s
#
# 2022-01-16 16:51:43 (108 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
#class list
# !wget https://raw.githubusercontent.com/AlexeyAB/darknet/master/data/coco.names
# Out:
# --2022-01-16 16:51:43--  https://raw.githubusercontent.com/AlexeyAB/darknet/master/data/coco.names
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 625 [text/plain]
# Saving to: ‘coco.names’
#
# coco.names          100%[===================>]     625  --.-KB/s    in 0s
#
# 2022-01-16 16:51:43 (38.4 MB/s) - ‘coco.names’ saved [625/625]

# %% [markdown]
# #convert

# %% [markdown]
# ##weight to pb

# %%
# !mkdir /content/converter

# %%
# %cd /content/converter
# Out:
# /content/converter

# %%
# !wget https://github.com/mystic123/tensorflow-yolo-v3/archive/ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3.zip
# Out:
# --2022-01-16 16:52:01--  https://github.com/mystic123/tensorflow-yolo-v3/archive/ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3.zip
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/mystic123/tensorflow-yolo-v3/zip/ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3 [following]
# --2022-01-16 16:52:01--  https://codeload.github.com/mystic123/tensorflow-yolo-v3/zip/ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3
# Resolving codeload.github.com (codeload.github.com)... 192.30.255.120
# Connecting to codeload.github.com (codeload.github.com)|192.30.255.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3.zip’
#
# ed60b9087b04e1d9ca4     [ <=>                ]  18.64K  --.-KB/s    in 0.007s
#
# ...

# %%
# !sudo apt-get install unzip
# !unzip ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3.zip -d tensorflow-yolo-v3
# %cd tensorflow-yolo-v3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Archive:  ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3.zip
# ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3
#    creating: tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3/
#   inflating: tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3/.gitignore
#   inflating: tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3/CODE_OF_CONDUCT.md
#   inflating: tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3/LICENSE
#   inflating: tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3/README.md
#   inflating: tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3/convert_weights.py
# ...

# %%
# %cd /content/converter/tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3
# Out:
# /content/converter/tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3

# %%
# !python3 convert_weights_pb.py --class_names /content/coco.names --data_format NHWC --weights_file /content/yolov3.weights
# !python3 convert_weights_pb.py --class_names /content/coco.names --data_format NHWC --weights_file /content/csresnext50-panet-spp-original-optimal_final.weights
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From convert_weights_pb.py:52: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From convert_weights_pb.py:38: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0116 17:32:32.374428 140106727421824 module_wrapper.py:139] From convert_weights_pb.py:38: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From convert_weights_pb.py:40: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
import shutil

# %%
shutil.copy("/content/converter/tensorflow-yolo-v3/tensorflow-yolo-v3-ed60b9087b04e1d9ca40f8a9d8455d5c30c7c0d3/frozen_darknet_yolov3_model.pb","/content/drive/MyDrive/CE_Project/model/saved_model.pb")
# Out:
# '/content/drive/MyDrive/CE_Project/model/saved_model.pb'

# %% [markdown]
# #another try
