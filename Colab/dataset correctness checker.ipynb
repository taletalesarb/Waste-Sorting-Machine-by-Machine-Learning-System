# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os

# %%
dir = '/content/gdrive/MyDrive/CE_Project/Dataset/labeled/labels/'
fileNames_txt = [os.path.splitext(filename)[0] for filename in os.listdir(dir)]
dir = '/content/gdrive/MyDrive/CE_Project/Dataset/labeled/images/'
fileNames_img = [os.path.splitext(filename)[0] for filename in os.listdir(dir)]

# %%
len(fileNames_txt)
# Out:
# 1622

# %%
len(fileNames_img)
# Out:
# 1515

# %%
temp_txt = fileNames_txt
temp_img = fileNames_img

# %%
count =0
not_in_txt = []
for i in fileNames_img:
  if i not in fileNames_txt:
    not_in_txt.append(i)
    count += 1
print(count)
not_in_txt.sort()
for i in not_in_txt:
  print(i)
# Out:
# 105
# Aerosol_cans109
# Aerosol_cans18
# Battery19
# Cleaning_solution16
# Correction_fluid15
# Drinking_straw51
# Foam_box101
# Foam_box152
# Foam_box236
# Foam_box38
# Foam_box49
# Foam_box59
# Foam_box60
# Foam_box83
# Foam_box97
# Light_bulb111
# Three_eye_plug13
# carton290
# carton360
# glass_bottle323
# glass_bottle383
# glass_bottle420
# glass_bottle432
# plastic_bag110
# plastic_bag130
# plastic_bottle0
# plastic_bottle10
# plastic_bottle100
# plastic_bottle101
# plastic_bottle103
# plastic_bottle105
# plastic_bottle107
# plastic_bottle108
# plastic_bottle109
# plastic_bottle111
# plastic_bottle114
# plastic_bottle116
# plastic_bottle121
# plastic_bottle122
# plastic_bottle123
# plastic_bottle124
# plastic_bottle125
# plastic_bottle126
# plastic_bottle127
# plastic_bottle128
# plastic_bottle129
# plastic_bottle13
# plastic_bottle130
# plastic_bottle14
# plastic_bottle151
# plastic_bottle16
# plastic_bottle17
# plastic_bottle182
# plastic_bottle19
# plastic_bottle2
# ...

# %%
count = 0
not_in_img=[]
for i in fileNames_txt:
  if i not in fileNames_img:
    not_in_img.append(i)
    count += 1
print(count)
not_in_img.sort()
for i in not_in_img:
  print(i)
# Out:
# 212
# Aerosol_cans1
# Aerosol_cans10
# Battery1
# Battery10
# Cleaning_solution1
# Cleaning_solution10
# Correction_fluid1
# Correction_fluid10
# Drinking_straw1
# Drinking_straw11
# Drinking_straw14
# Drinking_straw16
# Drinking_straw17
# Drinking_straw18
# Drinking_straw5
# Drinking_straw6
# Drinking_straw7
# Drinking_straw8
# Foam_box1
# Foam_box10
# Foam_box2
# Foam_box3
# Foam_box4
# Foam_box5
# Foam_box6
# Foam_box8
# Foam_box9
# Insecticide10
# Light_bulb11
# Three_eye_plug1
# bottle0
# bottle1
# bottle10
# bottle100
# bottle101
# bottle102
# bottle103
# bottle105
# bottle107
# bottle108
# bottle109
# bottle11
# bottle111
# bottle114
# bottle116
# bottle12
# bottle121
# bottle122
# bottle123
# bottle124
# bottle125
# bottle126
# bottle127
# bottle128
# bottle129
# bottle13
# bottle130
# bottle14
# bottle15
# bottle16
# bottle17
# bottle18
# bottle19
# bottle2
# bottle20
# bottle21
# bottle22
# bottle23
# bottle24
# bottle25
# bottle27
# bottle28
# bottle3
# bottle31
# ...
