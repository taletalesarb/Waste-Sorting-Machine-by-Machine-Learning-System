# %%
# !pip install -Iv 'numpy~=1.19.2' --force-reinstall
# !pip install -Iv 'six~=1.15.0' --force-reinstall
# !pip install -Iv 'pandas~=1.1.0' --force-reinstall
# !pip install -Iv 'imgaug<0.2.7,>=0.2.5' --force-reinstall
# !pip install -Iv 'six~=1.15.0' --force-reinstall

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo


# !pip install -U -r yolov5/requirements.txt  # install dependencies

# %cd /content/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9841, done.
# remote: Total 9841 (delta 0), reused 0 (delta 0), pack-reused 9841
# Receiving objects: 100% (9841/9841), 10.23 MiB | 19.68 MiB/s, done.
# Resolving deltas: 100% (6812/6812), done.
# ...
#      |████████████████████████████████| 10.3 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 58 kB/s
# ...
#      |████████████████████████████████| 60.3 MB 37 kB/s
# ...
#      |████████████████████████████████| 3.1 MB 32.6 MB/s
# ...
#      |████████████████████████████████| 596 kB 45.3 MB/s
# ...
#      |████████████████████████████████| 62 kB 850 kB/s
# ...
#      |████████████████████████████████| 28.5 MB 48 kB/s
# ...

# %%
# !pip install utils

# %%
# pip install google-utils

# %%
import torch
from IPython.display import Image  # for displaying images
# from utils.google_utils import gdrive_download  # for downloading models/datasets
# from google_utils import gdrive_download  # for downloading models/datasets

print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 1.9.0+cu102 _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from torchsummary import summary
summary(model)
